# %% [markdown]
# # Coloring a partition of the county #

# %%
from pgraph import PGraph
from path_generator import get_paths
from drawing import *

# %%
county_name = 'Cumberland'
G = PGraph.from_data(*get_paths(county_name))

# %%
ax = get_axes(G)
show()

# %%
subset = [12, 13, 18, 35]
ax = get_axes(G)
color_subset(G, subset, ax)
draw_convex_hull(G, subset, ax)
draw_enclosing_circle(G, subset, ax)
show()

# %%
subsets = [[0, 38, 2, 7], 
           [1, 3, 4, 5, 6], 
           [10, 11, 12, 13],
           [14, 15, 16], [17, 18]]
ax = get_axes(G)
color_subsets(G, subsets, ax, ['red', 'blue', 'green', 'yellow', 'purple'])
show()

# %%
ax = get_axes(G)
color_by_votes(G, ax)
show()

# %%
subset = [4, 5, 7, 30]
PGraph.calculate_efficiency_gap(G, subset)
# Out:
# 0.10780563819237853

# %%
PGraph.calculate_isoperimetric_quotient(G, subset)
# Out:
# 0.0015424895090231528
